# %%
import matplotlib.pyplot as plt
 
x=[2,6]
y=[4,9]
x1=[8,3]
y1=[4,7]

plt.xlabel("Time")
plt.ylabel("Speed")
plt.plot(x, y, label ="river")
plt.plot(x1, y1, label="railway")
plt.legend()
plt.grid(color='r')
